# 25508 -0.017938  0.047280  0.030045 -0.003770  0.001868  0.012550  0.007418
# 25509  0.004033  0.008324  0.005055 -0.000926 -0.001808  0.001258  0.003365
# 25510  0.000470  0.034188  0.003268  0.000105 -0.000157  0.000238  0.000178
# 25511  0.029709  0.027671  0.056606  0.001022  0.004146  0.002198  0.008351
# 25512 -0.015870  0.067770  0.075067 -0.011273 -0.011643  0.015161  0.016654
# 25513  0.006431  0.031555  0.078236 -0.002959 -0.003161  0.004291  0.010299
# 25514 -0.008898  0.043128  0.018078 -0.004418  0.001166  0.005132  0.003620
# 25515  0.012094  0.031915  0.022290 -0.001113 -0.004933  0.005693  0.011226
# 25516 -0.006990  0.032958  0.029020 -0.000643  0.000804  0.004039  0.003783
# 25517 -0.040199  0.041338  0.055789 -0.005483 -0.004252  0.006401  0.007561
#
#        4804
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# 5       1.0
# 6       1.0
# 7       1.0
# 8       1.0
# 9       1.0
# 10      1.0
# 11      1.0
# 12      1.0
# 13      1.0
# 14      1.0
# 15      1.0
# 16      1.0
# 17      1.0
# 18      1.0
# 19      1.0
# 20      1.0
# 21      1.0
# 22      1.0
# 23      1.0
# 24      1.0
# 25      1.0
# 26      1.0
# 27      1.0
# 28      1.0
# 29      1.0
# ...     ...
# 25488  42.0
# 25489  42.0
# 25490  42.0
# 25491  42.0
# 25492  42.0
# 25493  42.0
# 25494  42.0
# 25495  42.0
# 25496  42.0
# 25497  42.0
# 25498  42.0
# 25499  42.0
# 25500  42.0
# 25501  42.0
# 25502  42.0
# 25503  42.0
# 25504  42.0
# 25505  42.0
# 25506  42.0
# 25507  42.0
# 25508  42.0
# 25509  42.0
# 25510  42.0
# 25511  42.0
# 25512  42.0
# 25513  42.0
# 25514  42.0
# 25515  42.0
# 25516  42.0
# 25517  42.0
#
# [25518 rows x 4807 columns]

# %%
def get_label_indices(data):

# %%
X = np.array(data.iloc[:,2:4806])
y = data.iloc[:,-1]
y = np.array(y).reshape([-1,1])

# print(X[:,-1])
# print(y)
# print(X)
num_classes = int(np.max(y))
train_t = None
val_t = None
train_y = None
val_y = None

for i in range(1,num_classes + 1):
    indices = np.where(y == i)
    train_id = indices[0][0] + int(0.8*len(indices[0]))
    # print(indices)
    # print(train_id)
    x_train = X[indices[0][0]:train_id,:]
    x_val = X[train_id:indices[0][-1],:]
    y_train = (y[indices[0][0]:train_id,0]).reshape([-1,1])
    y_val = (y[train_id:indices[0][-1],0]).reshape([-1,1])
    
#     print(x_train.shape)
#     print(x_val.shape)
    if i == 1:
        train_t = x_train
        val_t = x_val
        train_y = y_train
        val_y = y_val
    else:
        train_t = np.vstack((train_t,x_train))
        val_t = np.vstack((val_t,x_val))
        train_y = np.vstack((train_y,y_train))
        val_y = np.vstack((val_y,y_val))

print(val_t.shape)
print(train_t.shape)
print(val_y.shape)
print(train_y.shape)

X_train,y_train,X_val,y_val = train_t,train_y,val_t,val_y

# print(num_classes)
min_in_y = np.min(y)
# print(num_classes)
# print(min_in_y)
# print(y[2069,0])
# print(y.shape)
# print(X.shape)
y_one_hot = np.zeros((X.shape[0],num_classes))
y_one_hot_train = np.zeros((X_train.shape[0],num_classes))
y_one_hot_val = np.zeros((X_val.shape[0],num_classes))

# print(y_one_hot.shape)

for i in range(y_train.shape[0]):
    y_one_hot_train[i,int(y_train[i,0])-1] = 1
for i in range(y_val.shape[0]):
    y_one_hot_val[i,int(y_val[i,0])-1] = 1
# Out:
# (5073, 4804)
# (20403, 4804)
# (5073, 1)
# (20403, 1)

# %%
print(X_train.shape)
print(y_one_hot_train.shape)
print(y_one_hot_val.shape)
print(X_val.shape)
# Out:
# (20403, 4804)
# (20403, 42)
# (5073, 42)
# (5073, 4804)

# %%
#Two layer NN
num_features = X.shape[1]
reg = 0.01

hidden_1 = 500 #layers in first hidden
hidden_2 = 100 #second layer

tf.reset_default_graph()
X_tf = tf.placeholder(name='X_tf',shape=[None,num_features],dtype=tf.float32)
y_tf = tf.placeholder(name='y_tf',shape=[None,num_classes],dtype=tf.float32)

W1 = tf.get_variable(name='W1',shape=[num_features,hidden_1],initializer=tf.contrib.layers.xavier_initializer(seed=1))
b1 = tf.get_variable(name='b1',shape=[1,hidden_1],initializer=tf.zeros_initializer())
W2 = tf.get_variable(name='W2',shape=[hidden_1,hidden_2],initializer=tf.contrib.layers.xavier_initializer(seed=1))
b2 = tf.get_variable(name='b2',shape=[1,hidden_2],initializer=tf.zeros_initializer())
W3 = tf.get_variable(name='W3',shape=[hidden_2,num_classes],initializer=tf.contrib.layers.xavier_initializer(seed=1))
b3 = tf.get_variable(name='b3',shape=[1,num_classes],initializer=tf.zeros_initializer())

# %%
z1 = tf.matmul(X_tf,W1) + b1
a1 = tf.nn.relu(z1)
z2 = tf.matmul(a1,W2) + b2
a2 = tf.nn.relu(z2)
z3 = tf.matmul(a2,W3) + b3

a3 = tf.nn.softmax(z3)

y_hat = tf.argmax(a3,axis=1)
print(y_hat.shape)
y_compare = tf.argmax(y_tf,axis=1)
print(y_compare.shape)
accuracy_ = tf.reduce_mean(tf.cast(tf.equal(y_hat,y_compare),tf.float32))

reg_loss = reg*(tf.nn.l2_loss(W1) + tf.nn.l2_loss(W2) + tf.nn.l2_loss(W3))
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=z3,labels=y_tf)) + reg_loss
# Out:
# (?,)
# (?,)
# WARNING:tensorflow:From <ipython-input-4-199e1b9a2c96>:16: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
global_step = tf.Variable(0, trainable=False)
learning_rate = tf.train.exponential_decay(0.005, global_step,10, 0.5, staircase=True)

trainer = tf.train.AdamOptimizer(learning_rate)
train_step = trainer.minimize(loss)

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

num_epochs = 100
batch_size = 1024

loss_vector = []
train_acc_vector = []
val_acc_vector = []

for epoch in range(num_epochs):
    print('Epoch ' + str(epoch) + ' chal rha hai abhi')
    
    perms = np.random.permutation(X_train.shape[0])
    num_batches = (int)(X_train.shape[0]/batch_size)
    
    X_shuffle = X_train[perms,:]
    y_shuffle = y_one_hot_train[perms,:]
    
    epoch_loss = 0.0
    epoch_acc = 0.0
    epoch_val_acc = 0.0
    
    lr = 1.0
    for i in range(num_batches):
        X_batch = X_shuffle[i*batch_size:(i+1)*batch_size,:]
        y_batch = y_shuffle[i*batch_size:(i+1)*batch_size,:]
        
        _,l,acc,lr = sess.run([train_step,loss,accuracy_,learning_rate],feed_dict={X_tf:X_batch,y_tf:y_batch})
    
        epoch_loss+=l
        epoch_acc+=acc
        
    val_acc_list = sess.run([accuracy_],feed_dict={X_tf:X_val,y_tf:y_one_hot_val})    
    val_acc = val_acc_list[0]

    print('Learning Rate chal rha hai : ' + str(lr))
    loss_vector.append(epoch_loss/(num_batches*1.0))
    train_acc_vector.append(epoch_acc/(num_batches*1.0))
    val_acc_vector.append(val_acc)
    
    if epoch%10 == 0:
        print('Epoch = '+ str(epoch))
        print('Loss = ' + str(epoch_loss/(num_batches*1.0)))
        print('Accuracy = ' + str(epoch_acc/(num_batches*1.0)))
        print('Validation Accuracy = ' + str(val_acc))
# Out:
# Epoch 0 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch = 0
# Loss = 5.766887915761847
# Accuracy = 0.16447368421052633
# Validation Accuracy = 0.36763257
# Epoch 1 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 2 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 3 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 4 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 5 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 6 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 7 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 8 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 9 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 10 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch = 10
# Loss = 1.6461310512141178
# Accuracy = 0.7380756578947368
# Validation Accuracy = 0.78080034
# Epoch 11 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 12 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 13 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 14 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 15 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 16 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 17 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 18 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 19 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 20 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch = 20
# Loss = 1.296645722891155
# Accuracy = 0.8807565789473685
# Validation Accuracy = 0.8941455
# Epoch 21 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 22 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 23 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 24 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 25 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 26 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 27 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 28 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 29 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 30 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch = 30
# Loss = 1.137688122297588
# Accuracy = 0.9197676809210527
# Validation Accuracy = 0.91464615
# Epoch 31 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 32 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 33 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 34 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 35 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 36 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 37 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 38 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 39 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 40 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch = 40
# Loss = 1.1117997483203286
# Accuracy = 0.9336965460526315
# Validation Accuracy = 0.9203627
# Epoch 41 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 42 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 43 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 44 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 45 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 46 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 47 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 48 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 49 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 50 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch = 50
# Loss = 1.1454327922118337
# Accuracy = 0.9218236019736842
# Validation Accuracy = 0.93435836
# Epoch 51 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 52 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 53 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 54 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 55 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 56 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 57 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 58 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 59 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 60 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch = 60
# Loss = 1.0756316435964484
# Accuracy = 0.9408922697368421
# Validation Accuracy = 0.9041987
# Epoch 61 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 62 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 63 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 64 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 65 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 66 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 67 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 68 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 69 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 70 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch = 70
# Loss = 1.096954948023746
# Accuracy = 0.9297902960526315
# Validation Accuracy = 0.9195742
# Epoch 71 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 72 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 73 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 74 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 75 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 76 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 77 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 78 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 79 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 80 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch = 80
# Loss = 1.2185826176091243
# Accuracy = 0.8949424342105263
# Validation Accuracy = 0.92726195
# Epoch 81 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 82 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 83 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 84 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 85 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 86 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 87 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 88 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 89 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 90 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch = 90
# Loss = 1.0502932761844836
# Accuracy = 0.9491159539473685
# Validation Accuracy = 0.95111376
# Epoch 91 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 92 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 93 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 94 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 95 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 96 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 97 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 98 chal rha hai abhi
# Learning Rate chal rha hai : 0.005
# Epoch 99 chal rha hai abhi
# Learning Rate chal rha hai : 0.005

# %%
epochs = [i for i in range(num_epochs)]
plt.plot(epochs,loss_vector)
plt.figure()
plt.plot(epochs,val_acc_vector)
plt.plot(epochs,train_acc_vector)
plt.show()

# %%
saver = tf.train.Saver({"W1":W1,"b1":b1,"W2":W2,"b2":b2,"W3":W3,"b3":b3})
save_path = saver.save(sess, "/tmp/model.ckpt")

# %%
'''
TODO: 
Try On Test Images
BatchNorm
'''
